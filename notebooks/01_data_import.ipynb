# %% [markdown]
# # Freight Forwarding Shipment Exception Monitoring
#
# ## Notebook 01 - Data Import

# %% [markdown]
# ## Objective
#
# This notebook imports the raw freight forwarding datasets into pandas DataFrames and verifies their initial structure before any profiling or cleaning is performed.
#
# This step is limited to confirming that the expected files can be loaded, reviewing dataframe dimensions, and inspecting column names and inferred data types. Detailed profiling, data quality assessment, cleaning, transformation, validation, visualization, and analysis are intentionally handled in later pipeline stages.

# %% [markdown]
# ## Import Libraries
#
# Import the required libraries and project configuration values. File paths are sourced from the shared configuration module rather than hardcoded in the notebook.

# %%
from pathlib import Path
import sys

import pandas as pd

PROJECT_ROOT = next(
    path
    for path in [Path.cwd(), *Path.cwd().parents]
    if (path / "scripts" / "config.py").exists()
)

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from scripts.config import RAW_DATA_DIR

# %% [markdown]
# ## Load Raw Datasets
#
# Load the three raw Excel datasets from the project raw data directory into clearly named pandas DataFrames.

# %%
shipments_df = pd.read_excel(RAW_DATA_DIR / "shipments.xlsx")
milestones_df = pd.read_excel(RAW_DATA_DIR / "shipment_milestones.xlsx")
issue_log_df = pd.read_excel(RAW_DATA_DIR / "issue_log.xlsx")

# %% [markdown]
# ## Verify Data Import
#
# Inspect each imported DataFrame individually for readability. This section reviews sample rows, dataframe dimensions, column structure, and inferred data types only.

# %% [markdown]
# ### Shipments DataFrame

# %%
shipments_df.head()
# Out:
#   Shipment ID Booking Number BL Number               Customer Name Incoterm  \
# 0     SHP0001      BKG000001  BL000001  PT Orion Consumer Products      FOB
# 1     SHP0002      BKG000002  BL000002     PT Evergreen Industrial      EXW
# 2     SHP0003      BKG000003  BL000003     PT Vertex Manufacturing      CIF
# 3     SHP0004      BKG000004  BL000004         PT Nova Electronics      FOB
# 4     SHP0005      BKG000005  BL000005        PT Zenith Industrial      EXW
#
#   Cargo Type             Commodity  Cargo Volume CBM Container Type  \
# 0        LCL              Textiles   07:09:59.999000           40HC
# 1        FCL             Chemicals   06:09:59.999000           20GP
# 2        LCL              Textiles             39.63           40GP
# 3        LCL             Chemicals             68.63           20GP
# 4        FCL  Consumer Electronics  2 days, 18:34:00           40GP
#
#    Container Qty  ...     Actual Departure Actual Arrival Cut Off Time  \
# 0              4  ...                  NaN            NaN   2025-06-30
# 1              5  ...           2025-08-23            NaN   2025-08-20
# 2              8  ...  2024-03-01 18:00:00            NaN   2024-02-29
# 3              8  ...  2024-03-15 21:00:00            NaN   2024-03-13
# 4              8  ...           2024-10-04            NaN   2024-10-01
#
#   Closing Time    Total Charge USD    Shipment Status Priority Level  \
# 0   2025-07-01   188 days, 2:00:00          At Origin            Low
# 1   2025-08-21             6099.60         In Transit           High
# 2   2024-03-01  322 days, 22:20:00         In Transit            Low
# 3   2024-03-14   336 days, 9:20:00  Customs Clearance           Low
# 4   2024-10-02             7809.60          At Origin            Low
#
#         PIC Name Created Date Last Update Timestamp
# 0   Cindy Wijaya   2025-06-22            2025-07-06
# 1  Yoga Mahendra   2025-08-12            2025-09-10
# 2   Budi Santoso   2024-02-21            2024-03-12
# 3   Cindy Wijaya   2024-03-05            2024-03-27
# 4   Andi Pratama   2024-09-23            2024-10-23
#
# [5 rows x 26 columns]

# %%
shipments_df.shape
# Out:
# (500, 26)

# %%
shipments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Shipment ID            500 non-null    object
#  1   Booking Number         500 non-null    object
#  2   BL Number              493 non-null    object
#  3   Customer Name          500 non-null    object
#  4   Incoterm               500 non-null    object
#  5   Cargo Type             500 non-null    object
#  6   Commodity              500 non-null    object
#  7   Cargo Volume CBM       500 non-null    object
#  8   Container Type         500 non-null    object
#  9   Container Qty          500 non-null    int64
#  10  Origin Port            500 non-null    object
#  11  Destination Port       500 non-null    object
#  12  Vessel Name            500 non-null    object
#  13  Shipping Line          500 non-null    object
#  14  ETD                    500 non-null    object
#  15  ETA                    500 non-null    object
#  16  Actual Departure       432 non-null    object
#  17  Actual Arrival         245 non-null    object
#  18  Cut Off Time           500 non-null    object
#  19  Closing Time           500 non-null    object
#  20  Total Charge USD       500 non-null    object
#  21  Shipment Status        500 non-null    object
#  22  Priority Level         500 non-null    object
#  23  PIC Name               493 non-null    object
#  24  Created Date           500 non-null    object
#  25  Last Update Timestamp  493 non-null    object
# dtypes: int64(1), object(25)
# memory usage: 101.7+ KB

# %% [markdown]
# ### Shipment Milestones DataFrame

# %%
milestones_df.head()
# Out:
#   Milestone ID Shipment ID  Milestone Sequence          Milestone Type  \
# 0     MS000001     SHP0001                   1             Cargo Ready
# 1     MS000002     SHP0001                   2       Booking Confirmed
# 2     MS000003     SHP0001                   3  Empty Container Pickup
# 3     MS000004     SHP0001                   4           Cargo Loading
# 4     MS000005     SHP0001                   5                 Gate In
#
#   Planned Datetime      Actual Datetime Milestone Status     Updated By  \
# 0       2024-03-03  2024-03-03 12:00:00        Completed   Andi Pratama
# 1       2024-03-04  2024-03-04 08:00:00          Delayed  Fajar Nugroho
# 2       2024-03-08  2024-03-08 12:00:00          Delayed   Andi Pratama
# 3       2024-03-12           2024-03-12        Completed    Rafi Kurnia
# 4       2024-03-16  2024-03-16 12:00:00          Delayed  Dimas Saputra
#
#                     Update Notes     Update Timestamp
# 0      Shipment tracking updated  2024-03-05 12:00:00
# 1        Depot release completed  2024-03-06 08:00:00
# 2    Operational update recorded  2024-03-08 12:00:00
# 3    Shipping documents verified           2024-03-13
# 4  Operational note variation 80  2024-03-17 12:00:00

# %%
milestones_df.shape
# Out:
# (5000, 10)

# %%
milestones_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Milestone ID        5000 non-null   object
#  1   Shipment ID         5000 non-null   object
#  2   Milestone Sequence  5000 non-null   int64
#  3   Milestone Type      5000 non-null   object
#  4   Planned Datetime    5000 non-null   object
#  5   Actual Datetime     5000 non-null   object
#  6   Milestone Status    5000 non-null   object
#  7   Updated By          4870 non-null   object
#  8   Update Notes        4875 non-null   object
#  9   Update Timestamp    4871 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 390.8+ KB

# %% [markdown]
# ### Issue Log DataFrame

# %%
issue_log_df.head()
# Out:
#    Issue ID Shipment ID         Issue Type  \
# 0  ISS00001     SHP0397      Documentation
# 1  ISS00002     SHP0115  Amendment Request
# 2  ISS00003     SHP0191      Documentation
# 3  ISS00004     SHP0455    Port Congestion
# 4  ISS00005     SHP0002      Documentation
#
#                          Issue Description Severity Level Issue Status  \
# 0          Shipping instruction incomplete           High       Closed
# 1   Consignee requested shipment amendment         Medium         Open
# 2         Documentation submission delayed           High         Open
# 3  Berth congestion delayed vessel loading         Medium       Closed
# 4         Documentation submission delayed            Low         Open
#
#   Issue Open Date    Due Date Issue Closed Date   Assigned PIC  \
# 0      2024-11-01  2024-11-03        2024-11-16   Budi Santoso
# 1      2025-01-20  2025-01-28               NaN  Fajar Nugroho
# 2      2024-06-23  2024-07-05               NaN   Budi Santoso
# 3      2025-12-05  2025-12-16        2025-12-14    Kevin Halim
# 4      2025-12-13  2025-12-18               NaN   Budi Santoso
#
#               Corrective Action Root Cause Category  \
# 0   Verified booking adjustment                Port
# 1      Escalated customs review             Weather
# 2       Arranged customs review            Customer
# 3  Requested terminal follow up            Customer
# 4   Verified booking adjustment             Customs
#
#                                     Root Cause Notes Last Update Timestamp
# 0       Port related delay caused by late submission            2024-11-01
# 1  Weather related delay caused by operational ba...            2025-01-21
# 2  Customer related delay caused by system interr...            2024-06-25
# 3   Customer related delay caused by late submission            2025-12-08
# 4  Customs related delay caused by operational ba...            2025-12-13

# %%
issue_log_df.shape
# Out:
# (750, 14)

# %%
issue_log_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Issue ID               750 non-null    object
#  1   Shipment ID            750 non-null    object
#  2   Issue Type             750 non-null    object
#  3   Issue Description      750 non-null    object
#  4   Severity Level         750 non-null    object
#  5   Issue Status           750 non-null    object
#  6   Issue Open Date        750 non-null    object
#  7   Due Date               750 non-null    object
#  8   Issue Closed Date      355 non-null    object
#  9   Assigned PIC           750 non-null    object
#  10  Corrective Action      750 non-null    object
#  11  Root Cause Category    750 non-null    object
#  12  Root Cause Notes       750 non-null    object
#  13  Last Update Timestamp  750 non-null    object
# dtypes: object(14)
# memory usage: 82.2+ KB

# %% [markdown]
# ## Initial Observation
#
# The three raw datasets were successfully loaded into pandas DataFrames. The dataframe dimensions were verified using `shape`, and the column structure and inferred data types were inspected using `info`.
#
# Detailed data quality assessment, including completeness, duplicate review, value consistency, and other profiling checks, will be performed in Notebook 02 - Data Profiling.
